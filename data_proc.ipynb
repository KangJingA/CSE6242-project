# %%
import numpy as np
import pandas as pd
import os
from data.buses import LTA
from data_proc import *

# %%
# Import datasets
# df_bus_stop
current_folder_path = os.getcwd()
data_folder_name = "data"
bus_stop_path = os.path.join(current_folder_path, data_folder_name, 'bus_stops', 'all_bus_stops.csv')
df_bus_stops = pd.read_csv(bus_stop_path)
df_bus_stops
# Out:
#       BusStopCode           RoadName             Description  Latitude  \
# 0            1012        Victoria St     Hotel Grand Pacific  1.296848
# 1            1013        Victoria St         St. Joseph's Ch  1.297710
# 2            1019        Victoria St         Bras Basah Cplx  1.296990
# 3            1029      Nth Bridge Rd            Opp Natl Lib  1.296673
# 4            1039      Nth Bridge Rd              Bugis Cube  1.298208
# ...           ...                ...                     ...       ...
# 5104        99139  Changi Village Rd                   Blk 5  1.388195
# 5105        99161          Nicoll Dr   Bef Changi Beach CP 3  1.390262
# 5106        99171          Nicoll Dr       Changi Beach CP 2  1.391128
# 5107        99181      Telok Paku Rd  Bef S'pore Aviation Ac  1.387754
# 5108        99189      Telok Paku Rd      S'pore Aviation Ac  1.388414
#
#        Longitude
# 0     103.852536
# 1     103.853225
# 2     103.853022
# 3     103.854414
# 4     103.855491
# ...

# %%
# df_taps
tap_path = os.path.join(current_folder_path, data_folder_name, 'passenger_vol_by_bus_stops')
df_taps = get_df_from_zips(tap_path)
df_taps
# Out:
#        YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  \
# 0         2023-12  WEEKENDS/HOLIDAY           17.0     BUS    45379
# 1         2023-12           WEEKDAY           17.0     BUS    45379
# 2         2023-12           WEEKDAY           13.0     BUS    80051
# 3         2023-12  WEEKENDS/HOLIDAY           13.0     BUS    80051
# 4         2023-12  WEEKENDS/HOLIDAY           13.0     BUS     5319
# ...           ...               ...            ...     ...      ...
# 597311    2024-02           WEEKDAY            7.0     BUS    51011
# 597312    2024-02  WEEKENDS/HOLIDAY           18.0     BUS    70149
# 597313    2024-02           WEEKDAY           18.0     BUS    70149
# 597314    2024-02  WEEKENDS/HOLIDAY            6.0     BUS    13139
# 597315    2024-02           WEEKDAY            6.0     BUS    13139
#
#         TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# 0                       223                   162
# ...

# %%
# df_total_trips
total_trip_path = os.path.join(current_folder_path, data_folder_name, 'passenger_vol_by_OD_bus_stops')
df_total_trips = get_df_from_zips(total_trip_path)
df_total_trips
# Out:
#          YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 0           2023-12  WEEKENDS/HOLIDAY             17     BUS           24499
# 1           2023-12           WEEKDAY             17     BUS           24499
# 2           2023-12  WEEKENDS/HOLIDAY             10     BUS           65239
# 3           2023-12           WEEKDAY             10     BUS           65239
# 4           2023-12           WEEKDAY             16     BUS            3151
# ...             ...               ...            ...     ...             ...
# 16973858    2024-02  WEEKENDS/HOLIDAY             10     BUS           77009
# 16973859    2024-02           WEEKDAY             10     BUS           77009
# 16973860    2024-02           WEEKDAY             17     BUS           28661
# 16973861    2024-02  WEEKENDS/HOLIDAY             15     BUS           80159
# 16973862    2024-02           WEEKDAY             15     BUS           80159
#
#           DESTINATION_PT_CODE  TOTAL_TRIPS
# ...

# %%
# df_bus_route
bus_route_path = os.path.join(current_folder_path, data_folder_name, 'bus_routes', 'all_bus_routes.csv')
df_bus_route = pd.read_csv(bus_route_path)
df_bus_route
# Out:
#     ServiceNo Operator  Direction  StopSequence  BusStopCode  Distance  \
# 0          10     SBST          1             1        75009       0.0
# 1          10     SBST          1             2        76059       0.6
# 2          10     SBST          1             3        76069       1.1
# 3          10     SBST          1             4        96289       2.3
# 4          10     SBST          1             5        96109       2.7
# ..        ...      ...        ...           ...          ...       ...
# 495       105     SBST          1            12        52189       5.0
# 496       105     SBST          1            13        52079       6.1
# 497       105     SBST          1            14        51099       7.3
# 498       105     SBST          1            15        40249       8.2
# 499       105     SBST          1            16        40239       8.5
#
#      WD_FirstBus  WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# ...

# %%
# Preprocess dfs
df_2d = preprocess_df_bus_route_2d(df_bus_route)
df_total_trips = preprocess_totalTrips_df(df_total_trips)
df_distance_totalTrips = merge_distance_totalTrips(df_2d, df_total_trips)
df_taps = preprocess_df_taps(df_taps)
df_taps_distance_totalTrips = merge_taps_distance_totalTrips(df_taps, df_distance_totalTrips)
df_co2 = get_df_co2(df_taps_distance_totalTrips)

# %%
# Reformat the DataFrame
df_route = get_route_csv(df_co2)
df_route
# Out:
#   YEAR_MONTH ServiceNo    co2_by_car  co2_by_bus  co2_reduction  \
# 0    2023-12        10  3.457278e+08    1722.192   3.457261e+08
# 1    2023-12       100  4.220395e+07     928.944   4.220302e+07
# 2    2023-12       103  2.096601e+09   11443.440   2.096590e+09
# 3    2024-01        10  5.326620e+08    2301.744   5.326597e+08
# 4    2024-01       100  3.880841e+07     787.584   3.880762e+07
# 5    2024-01       103  2.175114e+09   11022.048   2.175103e+09
# 6    2024-02        10  4.322908e+08    2056.320   4.322887e+08
# 7    2024-02       100  5.200095e+07    1139.664   5.199981e+07
# 8    2024-02       103  1.847682e+09   10259.664   1.847672e+09
#
#    passenger_volume
# 0           4616018
# 1           1044668
# 2           4212830
# 3           5321198
# 4           1133036
# 5           4537686
# 6           4833926
# 7           1049178
# 8           4141034

# %%
# bar.csv
df_route_stops_taps = get_df_route_stops_taps(df_bus_route, df_bus_stops, df_taps)
df_bar = get_bar_csv(df_route_stops_taps)
df_bar
# Out:
#     ServiceNo  Direction  BusStopCode  Latitude   Longitude  all_taps
# 0          10          1         2119  1.291844  103.855343     58195
# 1          10          1         3019  1.284245  103.853108    269593
# 2          10          1         3059  1.281111  103.851461    296435
# 3          10          1         3129  1.278070  103.849567    433810
# 4          10          1         3217  1.275522  103.847944     76539
# ..        ...        ...          ...       ...         ...       ...
# 493       105          1        66019  1.346028  103.860404     13937
# 494       105          1        66029  1.350172  103.861435     56827
# 495       105          1        66399  1.351487  103.863246     22626
# 496       105          1        66409  1.349266  103.865939     29998
# 497       105          1        66419  1.350216  103.869309     42039
#
# [498 rows x 6 columns]
