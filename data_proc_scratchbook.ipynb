# %%
import numpy as np
import pandas as pd
import os
from data.buses import LTA
from data_proc import *

# %%
apiKey:str = "75cstockTLWN9wEcc9RE6Q=="

def to_df(data):
    data = pd.DataFrame.from_dict(data['value'])
    return data

lta = LTA(apiKey)

# %%
# Get df_bus_route
bus_route = lta.get_bus_routes()
df_bus_route = to_df(bus_route)
df_bus_route
# Out:
#     ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 0          10     SBST          1             1       75009       0.0
# 1          10     SBST          1             2       76059       0.6
# 2          10     SBST          1             3       76069       1.1
# 3          10     SBST          1             4       96289       2.3
# 4          10     SBST          1             5       96109       2.7
# ..        ...      ...        ...           ...         ...       ...
# 495       105     SBST          1            12       52189       5.0
# 496       105     SBST          1            13       52079       6.1
# 497       105     SBST          1            14       51099       7.3
# 498       105     SBST          1            15       40249       8.2
# 499       105     SBST          1            16       40239       8.5
#
#     WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 0          0500       2300         0500        2300         0500        2300
# 1          0502       2302         0502        2302         0502        2302
# 2          0504       2304         0504        2304         0503        2304
# 3          0508       2308         0508        2309         0507        2308
# 4          0509       2310         0509        2311         0508        2309
# ..          ...        ...          ...         ...          ...         ...
# 495        0604       0018         0604        0018         0617        0016
# 496        0607       0020         0606        0020         0620        0018
# 497        0610       0023         0609        0023         0623        0020
# 498        0612       0025         0611        0025         0625        0022
# 499        0613       0026         0612        0026         0626        0022
#
# [500 rows x 12 columns]

# %%
# preprocess_df_bus_route_1d: function to preprocess df_bus_route
# Input
df = df_bus_route

# Get ServiceNo with two directions
service_no_with_two_directions = df.groupby('ServiceNo')['Direction'].max()
service_no_with_two_directions = service_no_with_two_directions[service_no_with_two_directions == 2].index

# Filter the original DataFrame to include only ServiceNo with two directions
df = df[df['ServiceNo'].isin(service_no_with_two_directions)]

# Filter to include only Direction == 1 for each unique ServiceNo
df = df[df['Direction'] == 1] 

# Get the bus stop code when StopSequence is 1 for each bus
origin_bus_stop = df[df['StopSequence'] == 1].groupby('ServiceNo').agg(
    origin_bus_stop=('BusStopCode', 'first')
)
# Get the bus stop code when StopSequence is the max for each bus
destination_bus_stop = df.groupby('ServiceNo').agg(
    dest_bus_stop=('BusStopCode', 'last'),
    origin_dest_distance=('Distance', 'last')
)

# Merge origin_bus_stop into destination_bus_stop DataFrame
df_bus_route_processed = destination_bus_stop.merge(origin_bus_stop, left_index=True, right_index=True, how='left')

# Add Direction column
df_bus_route_processed['Direction'] = 1

# Reset index to make ServiceNo a column instead of index
df_bus_route_processed.reset_index(inplace=True)

# Reorder columns
df_bus_route_processed = df_bus_route_processed[['ServiceNo', 'Direction', 'origin_bus_stop', 'dest_bus_stop', 'origin_dest_distance']]

df_bus_route_processed
# Out:
#   ServiceNo  Direction origin_bus_stop dest_bus_stop  origin_dest_distance
# 0        10          1           75009         16009                  31.6
# 1       100          1           66009         11009                  24.7
# 2       103          1           66009         59009                  17.9

# %%
# preprocess_df_bus_route_2d: function to preprocess df_bus_route
# Input
df = df_bus_route

# Get ServiceNo with two directions
service_no_with_two_directions = df.groupby('ServiceNo')['Direction'].max()
service_no_with_two_directions = service_no_with_two_directions[service_no_with_two_directions == 2].index

# Filter the original DataFrame to include only ServiceNo with two directions
df = df[df['ServiceNo'].isin(service_no_with_two_directions)]

# Filter to include only Direction == 1 for each unique ServiceNo
df1 = df[df['Direction'] == 1]
df2 = df[df['Direction'] == 2]  

def process_df_by_serviceNo(df):
    # Get the bus stop code when StopSequence is 1 for each bus
    origin_bus_stop = df[df['StopSequence'] == 1].groupby('ServiceNo').agg(
        origin_bus_stop=('BusStopCode', 'first')
    )
    # Get the bus stop code when StopSequence is the max for each bus
    destination_bus_stop = df.groupby('ServiceNo').agg(
        dest_bus_stop=('BusStopCode', 'last'),
        origin_dest_distance=('Distance', 'last')
    )

    # Merge origin_bus_stop into destination_bus_stop DataFrame
    df_bus_route_processed = destination_bus_stop.merge(origin_bus_stop, left_index=True, right_index=True, how='left')

    # Add Direction column
    df_bus_route_processed['Direction'] = df['Direction'].unique()[0]

    # Reset index to make ServiceNo a column instead of index
    df_bus_route_processed.reset_index(inplace=True)

    # Reorder columns
    df_bus_route_processed = df_bus_route_processed[['ServiceNo', 'Direction', 'origin_bus_stop', 'dest_bus_stop', 'origin_dest_distance']]
    return df_bus_route_processed

df1_processed = process_df_by_serviceNo(df1)
df2_processed = process_df_by_serviceNo(df2)

# Concatenate the two DataFrames
concatenated_df = pd.concat([df1_processed, df2_processed])

# Sort the concatenated DataFrame by ServiceNo and Direction
sorted_df = concatenated_df.sort_values(by=['ServiceNo', 'Direction'])

# Reset the index
sorted_df.reset_index(drop=True, inplace=True)

print(df1_processed)
print(df2_processed)
print(sorted_df)
# Out:
#   ServiceNo  Direction origin_bus_stop dest_bus_stop  origin_dest_distance
# 0        10          1           75009         16009                  31.6
# 1       100          1           66009         11009                  24.7
# 2       103          1           66009         59009                  17.9
#   ServiceNo  Direction origin_bus_stop dest_bus_stop  origin_dest_distance
# 0        10          2           16009         75009                  31.9
# 1       100          2           11009         66009                  23.3
# 2       103          2           59009         66009                  17.8
#   ServiceNo  Direction origin_bus_stop dest_bus_stop  origin_dest_distance
# 0        10          1           75009         16009                  31.6
# 1        10          2           16009         75009                  31.9
# 2       100          1           66009         11009                  24.7
# 3       100          2           11009         66009                  23.3
# 4       103          1           66009         59009                  17.9
# 5       103          2           59009         66009                  17.8

# %%
# Test preprocess_df_bus_route_1d
df_1d = preprocess_df_bus_route_1d(df_bus_route)
df_1d
# Out:
#   ServiceNo  Direction origin_bus_stop dest_bus_stop  origin_dest_distance
# 0        10          1           75009         16009                  31.6
# 1       100          1           66009         11009                  24.7
# 2       103          1           66009         59009                  17.9

# %%
# Test preprocess_df_bus_route_2d
df_2d = preprocess_df_bus_route_2d(df_bus_route)
df_2d
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8

# %%
# Each 'ServiceNo' -> min-max 'StopSequence' -> min-max 'Distance' 
df_bus_route[df_bus_route['ServiceNo'] == '10']
# Out:
#     ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 0          10     SBST          1             1       75009       0.0
# 1          10     SBST          1             2       76059       0.6
# 2          10     SBST          1             3       76069       1.1
# 3          10     SBST          1             4       96289       2.3
# 4          10     SBST          1             5       96109       2.7
# ..        ...      ...        ...           ...         ...       ...
# 143        10     SBST          2            70       96101      29.1
# 144        10     SBST          2            71       96281      29.5
# 145        10     SBST          2            72       76061      30.8
# 146        10     SBST          2            73       76051      31.3
# 147        10     SBST          2            74       75009      31.9
#
#     WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 0          0500       2300         0500        2300         0500        2300
# 1          0502       2302         0502        2302         0502        2302
# 2          0504       2304         0504        2304         0503        2304
# 3          0508       2308         0508        2309         0507        2308
# 4          0509       2310         0509        2311         0508        2309
# ..          ...        ...          ...         ...          ...         ...
# 143        0658       0112         0721        0113         0730        0108
# 144        0659       0113         0722        0114         0732        0109
# 145        0705       0117         0726        0117         0736        0113
# 146        0707       0118         0728        0119         0737        0114
# 147        0707       0120         0730        0120         0739        0116
#
# [148 rows x 12 columns]

# %%
# 'Direction' == 1 and 'Direction' == 2 have different origin-destination distances, can take maximum of these too
    # Better to pick only 'Direction' == 1 since it reduces frontend work when plotting the bus stops
df_bus_route[(df_bus_route['ServiceNo'] == '10') & (df_bus_route['Direction'] == 1)]
# Out:
#    ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 0         10     SBST          1             1       75009       0.0
# 1         10     SBST          1             2       76059       0.6
# 2         10     SBST          1             3       76069       1.1
# 3         10     SBST          1             4       96289       2.3
# 4         10     SBST          1             5       96109       2.7
# ..       ...      ...        ...           ...         ...       ...
# 69        10     SBST          1            70       16051      30.4
# 70        10     SBST          1            71       16061      30.6
# 71        10     SBST          1            72       16071      30.8
# 72        10     SBST          1            73       16081      31.1
# 73        10     SBST          1            74       16009      31.6
#
#    WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 0         0500       2300         0500        2300         0500        2300
# 1         0502       2302         0502        2302         0502        2302
# 2         0504       2304         0504        2304         0503        2304
# 3         0508       2308         0508        2309         0507        2308
# 4         0509       2310         0509        2311         0508        2309
# ..         ...        ...          ...         ...          ...         ...
# 69        0623       0021         0618        0025         0617        0021
# 70        0624       0021         0618        0026         0617        0021
# 71        0625       0022         0619        0027         0618        0022
# 72        0626       0023         0620        0028         0619        0023
# 73        0627       0024         0622        0029         0621        0024
#
# [74 rows x 12 columns]

# %%
# start: 16009, end: 75009
df_bus_route[(df_bus_route['ServiceNo'] == '10') & (df_bus_route['Direction'] == 2)]
# Out:
#     ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 74         10     SBST          2             1       16009       0.0
# 75         10     SBST          2             2       16089       0.4
# 76         10     SBST          2             3       16079       0.7
# 77         10     SBST          2             4       16069       1.0
# 78         10     SBST          2             5       16059       1.3
# ..        ...      ...        ...           ...         ...       ...
# 143        10     SBST          2            70       96101      29.1
# 144        10     SBST          2            71       96281      29.5
# 145        10     SBST          2            72       76061      30.8
# 146        10     SBST          2            73       76051      31.3
# 147        10     SBST          2            74       75009      31.9
#
#     WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 74         0600       2400         0600        2400         0615        2400
# 75         0602       0002         0602        0001         0617        0001
# 76         0603       0003         0603        0002         0618        0002
# 77         0605       0004         0605        0003         0620        0003
# 78         0606       0005         0606        0004         0621        0004
# ..          ...        ...          ...         ...          ...         ...
# 143        0658       0112         0721        0113         0730        0108
# 144        0659       0113         0722        0114         0732        0109
# 145        0705       0117         0726        0117         0736        0113
# 146        0707       0118         0728        0119         0737        0114
# 147        0707       0120         0730        0120         0739        0116
#
# [74 rows x 12 columns]

# %%
# Loop service bus route?
    # Conclusion: only cares about 'Direction'=1, and max'Distance' from this direction 
df_bus_route[df_bus_route['ServiceNo'] == '101']
# Out:
#     ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 272       101     SBST          1             1       66009       0.0
# 273       101     SBST          1             2       62131       0.5
# 274       101     SBST          1             3       62141       0.9
# 275       101     SBST          1             4       63011       1.4
# 276       101     SBST          1             5       63021       1.9
# 277       101     SBST          1             6       63031       2.5
# 278       101     SBST          1             7       63041       2.8
# 279       101     SBST          1             8       63051       3.0
# 280       101     SBST          1             9       63061       3.3
# 281       101     SBST          1            10       64011       3.5
# 282       101     SBST          1            11       64541       4.1
# 283       101     SBST          1            12       64551       4.4
# 284       101     SBST          1            13       64529       4.6
# 285       101     SBST          1            14       64339       4.9
# 286       101     SBST          1            15       64341       5.1
# 287       101     SBST          1            16       64351       5.4
# 288       101     SBST          1            17       64431       5.9
# 289       101     SBST          1            18       64441       6.2
# 290       101     SBST          1            19       64461       6.5
# 291       101     SBST          1            20       66499       6.8
# 292       101     SBST          1            21       66541       7.1
# 293       101     SBST          1            22       66551       7.3
# 294       101     SBST          1            23       66561       7.5
# 295       101     SBST          1            24       66601       7.7
# 296       101     SBST          1            25       66571       7.8
# 297       101     SBST          1            26       66581       8.1
# 298       101     SBST          1            27       66549       8.6
# 299       101     SBST          1            28       66491       8.8
# 300       101     SBST          1            29       64619       9.1
# 301       101     SBST          1            30       64561       9.4
# 302       101     SBST          1            31       64359       9.9
# 303       101     SBST          1            32       64349      10.3
# 304       101     SBST          1            33       64331      10.7
# 305       101     SBST          1            34       64521      11.0
# 306       101     SBST          1            35       64559      11.2
# 307       101     SBST          1            36       64549      11.4
# 308       101     SBST          1            37       64019      12.0
# 309       101     SBST          1            38       63069      12.3
# 310       101     SBST          1            39       63059      12.6
# 311       101     SBST          1            40       63049      13.0
# 312       101     SBST          1            41       63039      13.4
# 313       101     SBST          1            42       63029      13.9
# 314       101     SBST          1            43       63019      14.5
# 315       101     SBST          1            44       62149      14.8
# 316       101     SBST          1            45       62189      15.0
# 317       101     SBST          1            47       66009      15.7
#
#     WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 272        0515       2400         0515        2400         0515        2400
# 273        0517       0002         0517        0002         0517        0002
# 274        0518       0003         0518        0003         0518        0003
# 275        0520       0005         0520        0005         0520        0005
# 276        0521       0007         0521        0007         0521        0007
# 277        0515       0009         0515        0009         0515        0009
# 278        0516       0010         0516        0010         0516        0010
# 279        0517       0011         0517        0011         0517        0011
# 280        0518       0012         0518        0013         0518        0012
# 281        0519       0013         0519        0014         0519        0013
# 282        0521       0015         0521        0016         0521        0015
# 283        0522       0017         0522        0017         0522        0016
# 284        0523       0018         0523        0018         0523        0017
# 285        0524       0019         0524        0020         0524        0019
# 286        0526       0021         0526        0021         0526        0020
# 287        0527       0022         0527        0022         0527        0021
# 288        0529       0025         0529        0025         0529        0024
# 289        0528       0026         0529        0026         0529        0025
# 290        0530       0028         0531        0027         0531        0026
# 291        0531       0029         0532        0029         0532        0028
# 292        0533       0031         0534        0030         0534        0029
# 293        0534       0032         0534        0031         0534        0030
# 294        0535       0033         0535        0032         0535        0031
# 295        0536       0034         0536        0033         0536        0032
# 296        0536       0034         0536        0033         0536        0032
# 297        0537       0035         0537        0034         0537        0033
# 298        0538       0036         0538        0035         0538        0034
# 299        0539       0037         0539        0036         0539        0035
# 300        0540       0038         0540        0037         0540        0036
# 301        0540       0039         0540        0038         0541        0037
# 302        0542       0041         0542        0040         0543        0039
# 303        0543       0042         0543        0041         0544        0040
# 304        0545       0043         0545        0042         0545        0041
# 305        0546       0044         0546        0043         0546        0042
# 306        0547       0045         0547        0044         0547        0043
# 307        0548       0046         0548        0045         0548        0044
# 308        0550       0048         0550        0047         0550        0046
# 309        0552       0049         0551        0048         0551        0047
# 310        0553       0050         0553        0049         0552        0048
# 311        0554       0051         0554        0050         0553        0049
# 312        0556       0053         0555        0052         0555        0051
# 313        0558       0054         0557        0053         0556        0052
# 314        0600       0056         0559        0055         0559        0054
# 315        0601       0057         0600        0056         0600        0055
# 316        0602       0058         0601        0057         0601        0056
# 317        0606       0101         0603        0101         0604        0100

# %%
# Bus 100
df_bus_route[(df_bus_route['ServiceNo'] == '100') & (df_bus_route['Direction'] == 2)]
# Out:
#     ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 205       100     SBST          2             1       11009       0.0
# 206       100     SBST          2             2       11359       0.2
# 207       100     SBST          2             3       11189       0.6
# 208       100     SBST          2             4       11179       0.8
# 209       100     SBST          2             5       11169       1.4
# 210       100     SBST          2             6       11059       2.0
# 211       100     SBST          2             7       11049       2.4
# 212       100     SBST          2             8       11039       2.8
# 213       100     SBST          2             9       11029       3.2
# 214       100     SBST          2            10       11519       3.8
# 215       100     SBST          2            11       18019       4.5
# 216       100     SBST          2            12       15059       5.0
# 217       100     SBST          2            13       15049       5.3
# 218       100     SBST          2            14       14189       5.7
# 219       100     SBST          2            15       14179       6.0
# 220       100     SBST          2            16       14169       6.4
# 221       100     SBST          2            17       14159       6.9
# 222       100     SBST          2            18       14139       7.3
# 223       100     SBST          2            19       14129       7.8
# 224       100     SBST          2            20       14119       8.1
# 225       100     SBST          2            21       14109       8.8
# 226       100     SBST          2            22       14089       9.2
# 227       100     SBST          2            23       14069      10.0
# 228       100     SBST          2            24       05641      10.6
# 229       100     SBST          2            25       03222      11.0
# 230       100     SBST          2            26       03111      11.7
# 231       100     SBST          2            27       03031      12.3
# 232       100     SBST          2            28       03011      12.9
# 233       100     SBST          2            29       02111      13.5
# 234       100     SBST          2            30       01611      14.1
# 235       100     SBST          2            31       01621      14.3
# 236       100     SBST          2            32       01511      14.6
# 237       100     SBST          2            33       01521      14.9
# 238       100     SBST          2            34       01411      15.2
# 239       100     SBST          2            35       01421      15.5
# 240       100     SBST          2            36       01341      16.0
# 241       100     SBST          2            37       80011      16.7
# 242       100     SBST          2            38       80031      17.2
# 243       100     SBST          2            39       80051      17.5
# 244       100     SBST          2            40       80071      17.9
# 245       100     SBST          2            41       80091      18.4
# 246       100     SBST          2            42       81081      18.6
# 247       100     SBST          2            43       81091      19.0
# 248       100     SBST          2            44       70011      19.4
# 249       100     SBST          2            45       70021      19.8
# 250       100     SBST          2            46       70031      20.1
# 251       100     SBST          2            47       70041      20.6
# 252       100     SBST          2            48       70051      20.9
# 253       100     SBST          2            49       70061      21.4
# 254       100     SBST          2            50       61031      21.9
# 255       100     SBST          2            51       61041      22.2
# 256       100     SBST          2            52       62111      22.6
# 257       100     SBST          2            53       62121      22.8
# 258       100     SBST          2            54       66009      23.3
#
#     WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 205        0600       2400         0600        2400         0600        2400
# 206        0601       0001         0601        0001         0601        0001
# 207        0603       0003         0603        0003         0603        0003
# 208        0604       0004         0604        0004         0604        0005
# 209        0607       0007         0607        0007         0606        0008
# 210        0609       0009         0609        0009         0608        0010
# 211        0610       0010         0610        0010         0609        0011
# 212        0612       0011         0611        0011         0610        0013
# 213        0613       0012         0612        0011         0610        0014
# 214        0615       0014         0614        0013         0612        0016
# 215        0617       0016         0616        0015         0614        0017
# 216        0619       0017         0617        0017         0615        0018
# 217        0620       0018         0618        0018         0616        0018
# 218        0621       0018         0619        0019         0616        0019
# 219        0622       0019         0620        0020         0617        0019
# 220        0623       0020         0621        0021         0618        0020
# 221        0624       0021         0623        0022         0619        0021
# 222        0626       0022         0624        0024         0621        0022
# 223        0627       0023         0626        0025         0622        0023
# 224        0628       0024         0627        0026         0623        0024
# 225        0629       0025         0628        0027         0624        0025
# 226        0630       0026         0629        0027         0624        0026
# 227        0633       0028         0632        0029         0626        0028
# 228        0634       0029         0633        0030         0627        0029
# 229        0636       0030         0634        0031         0628        0030
# 230        0638       0032         0636        0033         0630        0032
# 231        0640       0034         0638        0035         0632        0034
# 232        0642       0036         0640        0036         0633        0036
# 233        0645       0038         0642        0038         0636        0038
# 234        0647       0040         0644        0039         0638        0040
# 235        0648       0041         0645        0040         0639        0041
# 236        0649       0042         0646        0041         0640        0042
# 237        0649       0043         0648        0041         0642        0044
# 238        0630       0044         0649        0042         0643        0045
# 239        0632       0046         0650        0045         0645        0046
# 240        0633       0047         0652        0046         0646        0047
# 241        0635       0049         0654        0048         0647        0048
# 242        0636       0050         0656        0049         0648        0049
# 243        0638       0051         0657        0050         0649        0050
# 244        0640       0052         0659        0051         0650        0051
# 245        0642       0053         0702        0053         0652        0053
# 246        0643       0053         0703        0054         0653        0054
# 247        0645       0054         0704        0055         0654        0055
# 248        0647       0055         0706        0056         0655        0056
# 249        0648       0055         0707        0056         0656        0057
# 250        0650       0056         0708        0057         0657        0058
# 251        0652       0058         0709        0059         0659        0100
# 252        0654       0100         0710        0100         0700        0102
# 253        0656       0101         0712        0101         0701        0103
# 254        0658       0103         0713        0103         0702        0105
# 255        0659       0104         0715        0104         0703        0106
# 256        0701       0105         0716        0105         0704        0107
# 257        0702       0106         0717        0106         0705        0107
# 258        0705       0107         0720        0108         0708        0108

# %%
# Get df_bus_stop

# %%
# Load existing zipped data
current_folder_path = os.getcwd()
data_folder_name = "data"
data_file_name = "origin_destination_bus_202402.zip"
data_file_path = os.path.join(current_folder_path, data_folder_name, data_file_name)
df = pd.read_csv(data_file_path)
df
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 0          2024-02           WEEKDAY             16     BUS            4168
# 1          2024-02  WEEKENDS/HOLIDAY             16     BUS            4168
# 2          2024-02           WEEKDAY             14     BUS           80119
# 3          2024-02  WEEKENDS/HOLIDAY             14     BUS           80119
# 4          2024-02           WEEKDAY             17     BUS           44069
# ...            ...               ...            ...     ...             ...
# 5659682    2024-02  WEEKENDS/HOLIDAY             10     BUS           77009
# 5659683    2024-02           WEEKDAY             10     BUS           77009
# 5659684    2024-02           WEEKDAY             17     BUS           28661
# 5659685    2024-02  WEEKENDS/HOLIDAY             15     BUS           80159
# 5659686    2024-02           WEEKDAY             15     BUS           80159
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 0                      10051            4
# 1                      10051            3
# 2                      90079           12
# 3                      90079            2
# 4                      17229            5
# ...                      ...          ...
# 5659682                 5049            3
# 5659683                 5049            2
# 5659684                42071            1
# 5659685                11161            2
# 5659686                11161            1
#
# [5659687 rows x 7 columns]

# %%
# Preprocess total-trips df to get monthly origin-dest total trips
# Filter 'PT_TYPE' == 'BUS'
df = df[df['PT_TYPE'] == 'BUS']

# Group by YEAR_MONTH, ORIGIN_PT_CODE, DESTINATION_PT_CODE and sum TOTAL_TRIPS
condensed_df = df.groupby(['YEAR_MONTH', 'ORIGIN_PT_CODE', 'DESTINATION_PT_CODE']).agg({'TOTAL_TRIPS': 'sum'}).reset_index()

# Display the condensed DataFrame
print(condensed_df)
# Out:
#        YEAR_MONTH  ORIGIN_PT_CODE  DESTINATION_PT_CODE  TOTAL_TRIPS
# 0         2024-02            1012                 1112         2417
# 1         2024-02            1012                 1113         1907
# 2         2024-02            1012                 1121         1567
# 3         2024-02            1012                 1211         1490
# 4         2024-02            1012                 1311         1851
# ...           ...             ...                  ...          ...
# 334881    2024-02           99189                98139           21
# 334882    2024-02           99189                99019            1
# 334883    2024-02           99189                99029           14
# 334884    2024-02           99189                99039           26
# 334885    2024-02           99189                99049           62
#
# [334886 rows x 4 columns]

# %%
# Test proprocess_totalTrips_df
df_total_trips = preprocess_totalTrips_df(df)
df_total_trips
# Out:
#        YEAR_MONTH  ORIGIN_PT_CODE  DESTINATION_PT_CODE  TOTAL_TRIPS
# 0         2024-02            1012                 1112         2417
# 1         2024-02            1012                 1113         1907
# 2         2024-02            1012                 1121         1567
# 3         2024-02            1012                 1211         1490
# 4         2024-02            1012                 1311         1851
# ...           ...             ...                  ...          ...
# 334881    2024-02           99189                98139           21
# 334882    2024-02           99189                99019            1
# 334883    2024-02           99189                99029           14
# 334884    2024-02           99189                99039           26
# 334885    2024-02           99189                99049           62
#
# [334886 rows x 4 columns]

# %%
# df_2d
df_2d
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8

# %%
print(sorted_df.dtypes)
print(df_total_trips.dtypes)
# Out:
# ServiceNo                object
# Direction                 int64
# origin_bus_stop          object
# dest_bus_stop            object
# origin_dest_distance    float64
# dtype: object
# YEAR_MONTH             object
# ORIGIN_PT_CODE          int64
# DESTINATION_PT_CODE     int64
# TOTAL_TRIPS             int64
# dtype: object

# %%
# Merge df_total_trips into df_2d
merged_df = df_2d.merge(df_total_trips, 
                             left_on=['origin_bus_stop', 'dest_bus_stop'], 
                             right_on=['ORIGIN_PT_CODE', 'DESTINATION_PT_CODE'], 
                             how='left')
merged_df
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance  \
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8
#
#   YEAR_MONTH  ORIGIN_PT_CODE  DESTINATION_PT_CODE  TOTAL_TRIPS
# 0    2024-02           75009                16009           75
# 1    2024-02           16009                75009           60
# 2    2024-02           66009                11009           15
# 3    2024-02           11009                66009           86
# 4    2024-02           66009                59009          677
# 5    2024-02           59009                66009          520

# %%
# Test merge_distance_totalTrips
df_distance_totalTrips = merge_distance_totalTrips(df_2d, df_total_trips)
df_distance_totalTrips
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance  \
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8
#
#   YEAR_MONTH  ORIGIN_PT_CODE  DESTINATION_PT_CODE  TOTAL_TRIPS
# 0    2024-02           75009                16009           75
# 1    2024-02           16009                75009           60
# 2    2024-02           66009                11009           15
# 3    2024-02           11009                66009           86
# 4    2024-02           66009                59009          677
# 5    2024-02           59009                66009          520

# %%
# df_bus_stops
bus_stops = lta.get_bus_stops()
bus_stops = bus_stops['value']
nums =[500* i for i in range(1,11)]

for num in nums:
    bus_stops2 = lta.get_bus_stops2(num)  # modified method to generate dummy  * the api can call 500 record at once, so need to call multiple times to get all records
    bus_stops2 = bus_stops2['value']
    bus_stops.extend(bus_stops2)

print(len(bus_stops))
df_bus_stops =  pd.DataFrame.from_dict(bus_stops)
df_bus_stops
# Out:
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=500
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=1000
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=1500
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=2000
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=2500
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=3000
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=3500
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=4000
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=4500
# http://datamall2.mytransport.sg/ltaodataservice/BusStops?$skip=5000
# 5109
#      BusStopCode           RoadName             Description  Latitude  \
# 0          01012        Victoria St     Hotel Grand Pacific  1.296848
# 1          01013        Victoria St         St. Joseph's Ch  1.297710
# 2          01019        Victoria St         Bras Basah Cplx  1.296990
# 3          01029      Nth Bridge Rd            Opp Natl Lib  1.296673
# 4          01039      Nth Bridge Rd              Bugis Cube  1.298208
# ...          ...                ...                     ...       ...
# 5104       99139  Changi Village Rd                   Blk 5  1.388195
# 5105       99161          Nicoll Dr   Bef Changi Beach CP 3  1.390262
# 5106       99171          Nicoll Dr       Changi Beach CP 2  1.391128
# 5107       99181      Telok Paku Rd  Bef S'pore Aviation Ac  1.387754
# 5108       99189      Telok Paku Rd      S'pore Aviation Ac  1.388414
#
#        Longitude
# 0     103.852536
# 1     103.853225
# 2     103.853022
# 3     103.854414
# 4     103.855491
# ...          ...
# 5104  103.987234
# 5105  103.992957
# 5106  103.991021
# 5107  103.988503
# 5108  103.989716
#
# [5109 rows x 5 columns]

# %%
# df_taps
# filepath = 'transport_node_bus_202402.zip'
# taps = lta.get_passenger_vol_by_bus_stops(filepath)
# df_taps = to_df(taps)

# Path to your CSV file
csv_file_path = 'data/transport_node_bus_202402.csv'

# Read the CSV file into a DataFrame
df_taps = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
df_taps
# Out:
#        YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  PT_CODE  \
# 0         2024-02  WEEKENDS/HOLIDAY           17.0     BUS    45379
# 1         2024-02           WEEKDAY           17.0     BUS    45379
# 2         2024-02           WEEKDAY           13.0     BUS    80051
# 3         2024-02  WEEKENDS/HOLIDAY           13.0     BUS    80051
# 4         2024-02           WEEKDAY           13.0     BUS     5319
# ...           ...               ...            ...     ...      ...
# 198898    2024-02           WEEKDAY            7.0     BUS    51011
# 198899    2024-02  WEEKENDS/HOLIDAY           18.0     BUS    70149
# 198900    2024-02           WEEKDAY           18.0     BUS    70149
# 198901    2024-02  WEEKENDS/HOLIDAY            6.0     BUS    13139
# 198902    2024-02           WEEKDAY            6.0     BUS    13139
#
#         TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME
# 0                       190                   120
# 1                       442                   470
# 2                      2873                  2873
# 3                      1473                  1403
# 4                       109                   540
# ...                     ...                   ...
# 198898                 1851                  1870
# 198899                  391                   273
# 198900                 2088                  1547
# 198901                   37                   119
# 198902                  153                   332
#
# [198903 rows x 7 columns]

# %%
# Preprocess df_taps
df = df_taps

# Filter 'PT_TYPE' == 'BUS'
df = df[df['PT_TYPE'] == 'BUS']

# Group by YEAR_MONTH, PT_CODE, and sum TOTAL_TAP_IN_VOLUME TOTAL_TAP_OUT_VOLUME
condensed_df = df.groupby(['YEAR_MONTH', 'PT_CODE']).agg({'TOTAL_TAP_IN_VOLUME': 'sum', 'TOTAL_TAP_OUT_VOLUME': 'sum'}).reset_index()
condensed_df['TOTAL_TAP_VOLUME'] = condensed_df['TOTAL_TAP_IN_VOLUME'] + condensed_df['TOTAL_TAP_OUT_VOLUME']

# Display the condensed DataFrame
condensed_df
# Out:
#      YEAR_MONTH  PT_CODE  TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME  \
# 0       2024-02     1012                28041                 38209
# 1       2024-02     1013                22187                 16891
# 2       2024-02     1019                16367                 25547
# 3       2024-02     1029                34387                 22084
# 4       2024-02     1039                58100                 50405
# ...         ...      ...                  ...                   ...
# 5089    2024-02    99139                   36                 19201
# 5090    2024-02    99161                  146                   894
# 5091    2024-02    99171                  799                  4034
# 5092    2024-02    99181                13473                 13863
# 5093    2024-02    99189                 4197                  9697
#
#       TOTAL_TAP_VOLUME
# 0                66250
# 1                39078
# 2                41914
# 3                56471
# 4               108505
# ...                ...
# 5089             19237
# 5090              1040
# 5091              4833
# 5092             27336
# 5093             13894
#
# [5094 rows x 5 columns]

# %%
# Test preprocess_df_taps
df_taps = preprocess_df_taps(df_taps)
df_taps
# Out:
#      YEAR_MONTH  PT_CODE  TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME  \
# 0       2024-02     1012                28041                 38209
# 1       2024-02     1013                22187                 16891
# 2       2024-02     1019                16367                 25547
# 3       2024-02     1029                34387                 22084
# 4       2024-02     1039                58100                 50405
# ...         ...      ...                  ...                   ...
# 5089    2024-02    99139                   36                 19201
# 5090    2024-02    99161                  146                   894
# 5091    2024-02    99171                  799                  4034
# 5092    2024-02    99181                13473                 13863
# 5093    2024-02    99189                 4197                  9697
#
#       TOTAL_TAP_VOLUME
# 0                66250
# 1                39078
# 2                41914
# 3                56471
# 4               108505
# ...                ...
# 5089             19237
# 5090              1040
# 5091              4833
# 5092             27336
# 5093             13894
#
# [5094 rows x 5 columns]

# %%
# Check very large tap number
df_taps[df_taps['PT_CODE'] == 75009]
# Out:
#      YEAR_MONTH  PT_CODE  TOTAL_TAP_IN_VOLUME  TOTAL_TAP_OUT_VOLUME  \
# 4137    2024-02    75009              1177882               1177024
#
#       TOTAL_TAP_VOLUME
# 4137           2354906

# %%
# Merge df_taps in df_distance_totalTrips

# Merge the dataframes based on matching YEAR_MONTH and PT_CODE
merged_df = df_distance_totalTrips.merge(df_taps, 
                                         left_on=['YEAR_MONTH', 'ORIGIN_PT_CODE'], 
                                         right_on=['YEAR_MONTH', 'PT_CODE'], 
                                         how='left')

# Merge again for the destination PT_CODE
merged_df = merged_df.merge(df_taps, 
                             left_on=['YEAR_MONTH', 'DESTINATION_PT_CODE'], 
                             right_on=['YEAR_MONTH', 'PT_CODE'], 
                             suffixes=('_origin', '_destination'), 
                             how='left')

# Calculate the passenger volume by summing TOTAL_TAP_VOLUME from both origin and destination
merged_df['passenger_volume'] = merged_df['TOTAL_TAP_VOLUME_origin'] + merged_df['TOTAL_TAP_VOLUME_destination']

# Calculate the passenger volume by summing TOTAL_TAP_VOLUME from both origin and destination
merged_df['passenger_volume'] = merged_df['TOTAL_TAP_VOLUME_origin'] + merged_df['TOTAL_TAP_VOLUME_destination']

# Drop unnecessary columns
merged_df.drop(columns=['PT_CODE_origin', 'TOTAL_TAP_IN_VOLUME_origin', 'TOTAL_TAP_OUT_VOLUME_origin',  'PT_CODE_destination',
                        'TOTAL_TAP_IN_VOLUME_destination', 'TOTAL_TAP_OUT_VOLUME_destination', 'ORIGIN_PT_CODE', 'DESTINATION_PT_CODE'], inplace=True)

merged_df
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance  \
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8
#
#   YEAR_MONTH  TOTAL_TRIPS  TOTAL_TAP_VOLUME_origin  \
# 0    2024-02           75                  2354906
# 1    2024-02           60                    62057
# 2    2024-02           15                   470695
# 3    2024-02           86                    53894
# 4    2024-02          677                   470695
# 5    2024-02          520                  1599822
#
#    TOTAL_TAP_VOLUME_destination  passenger_volume
# 0                         62057           2416963
# 1                       2354906           2416963
# 2                         53894            524589
# 3                        470695            524589
# 4                       1599822           2070517
# 5                        470695           2070517

# %%
# Test merge_taps_distance_totalTrips
df_taps_distance_totalTrips = merge_taps_distance_totalTrips(df_taps, df_distance_totalTrips)
df_taps_distance_totalTrips
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance  \
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8
#
#   YEAR_MONTH  TOTAL_TRIPS  TOTAL_TAP_VOLUME_origin  \
# 0    2024-02           75                  2354906
# 1    2024-02           60                    62057
# 2    2024-02           15                   470695
# 3    2024-02           86                    53894
# 4    2024-02          677                   470695
# 5    2024-02          520                  1599822
#
#    TOTAL_TAP_VOLUME_destination  passenger_volume
# 0                         62057           2416963
# 1                       2354906           2416963
# 2                         53894            524589
# 3                        470695            524589
# 4                       1599822           2070517
# 5                        470695           2070517

# %%
# Compute bus/car CO2 emission
df = df_taps_distance_totalTrips
bus_CO2_rate = 0.48  # kg/km
car_CO2_rate = 0.167  # kg/km
bus2car_ratio = 1/4  # approximation: 1/4 passengers taking car and carpool
df['co2_by_bus'] = df['origin_dest_distance']*df['TOTAL_TRIPS']*bus_CO2_rate
df['co2_by_car'] = df['origin_dest_distance']*df['TOTAL_TRIPS']*df['passenger_volume']*bus2car_ratio*car_CO2_rate
df['co2_reduction'] = df['co2_by_car'] - df['co2_by_bus']
df
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance  \
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8
#
#   YEAR_MONTH  TOTAL_TRIPS  TOTAL_TAP_VOLUME_origin  \
# 0    2024-02           75                  2354906
# 1    2024-02           60                    62057
# 2    2024-02           15                   470695
# 3    2024-02           86                    53894
# 4    2024-02          677                   470695
# 5    2024-02          520                  1599822
#
#    TOTAL_TAP_VOLUME_destination  passenger_volume  co2_by_bus    co2_by_car  \
# 0                         62057           2416963    1137.600  2.391524e+08
# 1                       2354906           2416963     918.720  1.931383e+08
# 2                         53894            524589     177.840  8.114539e+06
# 3                        470695            524589     961.824  4.388641e+07
# 4                       1599822           2070517    5816.784  1.047555e+09
# 5                        470695           2070517    4442.880  8.001264e+08
#
#    co2_reduction
# 0   2.391513e+08
# 1   1.931374e+08
# 2   8.114362e+06
# 3   4.388545e+07
# 4   1.047550e+09
# 5   8.001220e+08

# %%
# Test df_co2
df_co2 = get_df_co2(df_taps_distance_totalTrips)
df_co2
# Out:
#   ServiceNo  Direction  origin_bus_stop  dest_bus_stop  origin_dest_distance  \
# 0        10          1            75009          16009                  31.6
# 1        10          2            16009          75009                  31.9
# 2       100          1            66009          11009                  24.7
# 3       100          2            11009          66009                  23.3
# 4       103          1            66009          59009                  17.9
# 5       103          2            59009          66009                  17.8
#
#   YEAR_MONTH  TOTAL_TRIPS  TOTAL_TAP_VOLUME_origin  \
# 0    2024-02           75                  2354906
# 1    2024-02           60                    62057
# 2    2024-02           15                   470695
# 3    2024-02           86                    53894
# 4    2024-02          677                   470695
# 5    2024-02          520                  1599822
#
#    TOTAL_TAP_VOLUME_destination  passenger_volume  co2_by_bus    co2_by_car  \
# 0                         62057           2416963    1137.600  2.391524e+08
# 1                       2354906           2416963     918.720  1.931383e+08
# 2                         53894            524589     177.840  8.114539e+06
# 3                        470695            524589     961.824  4.388641e+07
# 4                       1599822           2070517    5816.784  1.047555e+09
# 5                        470695           2070517    4442.880  8.001264e+08
#
#    co2_reduction
# 0   2.391513e+08
# 1   1.931374e+08
# 2   8.114362e+06
# 3   4.388545e+07
# 4   1.047550e+09
# 5   8.001220e+08

# %% [markdown]
# ## Checking df_OD_volume

# %%
# Load existing zipped data
current_folder_path = os.getcwd()
data_folder_name = "data"
data_file_name = "origin_destination_bus_202402.zip"
data_file_path = os.path.join(current_folder_path, data_folder_name, data_file_name)
df = pd.read_csv(data_file_path)
df
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 0          2024-02           WEEKDAY             16     BUS            4168
# 1          2024-02  WEEKENDS/HOLIDAY             16     BUS            4168
# 2          2024-02           WEEKDAY             14     BUS           80119
# 3          2024-02  WEEKENDS/HOLIDAY             14     BUS           80119
# 4          2024-02           WEEKDAY             17     BUS           44069
# ...            ...               ...            ...     ...             ...
# 5659682    2024-02  WEEKENDS/HOLIDAY             10     BUS           77009
# 5659683    2024-02           WEEKDAY             10     BUS           77009
# 5659684    2024-02           WEEKDAY             17     BUS           28661
# 5659685    2024-02  WEEKENDS/HOLIDAY             15     BUS           80159
# 5659686    2024-02           WEEKDAY             15     BUS           80159
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 0                      10051            4
# 1                      10051            3
# 2                      90079           12
# 3                      90079            2
# 4                      17229            5
# ...                      ...          ...
# 5659682                 5049            3
# 5659683                 5049            2
# 5659684                42071            1
# 5659685                11161            2
# 5659686                11161            1
#
# [5659687 rows x 7 columns]

# %%
# Bus 10
df[(df['ORIGIN_PT_CODE'] == 75009) & (df['DESTINATION_PT_CODE'] == 76051)]
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 338370     2024-02           WEEKDAY             20     BUS           75009
# 338371     2024-02  WEEKENDS/HOLIDAY             20     BUS           75009
# 695264     2024-02  WEEKENDS/HOLIDAY             14     BUS           75009
# 695267     2024-02           WEEKDAY             14     BUS           75009
# 1222117    2024-02           WEEKDAY             13     BUS           75009
# 1222120    2024-02  WEEKENDS/HOLIDAY             13     BUS           75009
# 1241832    2024-02           WEEKDAY              8     BUS           75009
# 1241833    2024-02  WEEKENDS/HOLIDAY              8     BUS           75009
# 1604870    2024-02           WEEKDAY             19     BUS           75009
# 2454098    2024-02           WEEKDAY             12     BUS           75009
# 2482582    2024-02           WEEKDAY             23     BUS           75009
# 3378574    2024-02           WEEKDAY             17     BUS           75009
# 3792106    2024-02           WEEKDAY             11     BUS           75009
# 3913228    2024-02  WEEKENDS/HOLIDAY             22     BUS           75009
# 4337098    2024-02  WEEKENDS/HOLIDAY             21     BUS           75009
# 4443339    2024-02           WEEKDAY             16     BUS           75009
# 4443340    2024-02  WEEKENDS/HOLIDAY             16     BUS           75009
# 5409989    2024-02  WEEKENDS/HOLIDAY             15     BUS           75009
# 5409990    2024-02           WEEKDAY             15     BUS           75009
# 5618875    2024-02  WEEKENDS/HOLIDAY             10     BUS           75009
# 5618877    2024-02           WEEKDAY             10     BUS           75009
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 338370                 76051            2
# 338371                 76051            2
# 695264                 76051            2
# 695267                 76051            4
# 1222117                76051            9
# 1222120                76051            1
# 1241832                76051            1
# 1241833                76051            1
# 1604870                76051            1
# 2454098                76051            6
# 2482582                76051            1
# 3378574                76051            3
# 3792106                76051            1
# 3913228                76051            1
# 4337098                76051            1
# 4443339                76051            5
# 4443340                76051            1
# 5409989                76051           10
# 5409990                76051            3
# 5618875                76051            2
# 5618877                76051            3

# %%
# Find rows where ORIGIN_PT_CODE equals DESTINATION_PT_CODE
    # Findings: No origin-destination total trips for loop service
df[df['ORIGIN_PT_CODE'] == df['DESTINATION_PT_CODE']]
# Out:
# Empty DataFrame
# Columns: [YEAR_MONTH, DAY_TYPE, TIME_PER_HOUR, PT_TYPE, ORIGIN_PT_CODE, DESTINATION_PT_CODE, TOTAL_TRIPS]
# Index: []

# %%
# Bus 101: loop service
# May need to get rid of loop-service bus (ex: 101) on the map, since there's no origin-destination total-trips for this bus

origin = 66009
destination = 62189
df[(df['ORIGIN_PT_CODE'] == origin) & (df['DESTINATION_PT_CODE'] == destination)]
# df[(df['ORIGIN_PT_CODE'] == origin)]
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 1090788    2024-02           WEEKDAY             14     BUS           66009
# 1924406    2024-02           WEEKDAY             17     BUS           66009
# 2459734    2024-02  WEEKENDS/HOLIDAY             21     BUS           66009
# 3103159    2024-02  WEEKENDS/HOLIDAY             16     BUS           66009
# 3103161    2024-02           WEEKDAY             16     BUS           66009
# 3568708    2024-02  WEEKENDS/HOLIDAY             12     BUS           66009
# 3700910    2024-02  WEEKENDS/HOLIDAY             11     BUS           66009
# 4459307    2024-02           WEEKDAY             20     BUS           66009
# 4797179    2024-02  WEEKENDS/HOLIDAY             10     BUS           66009
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 1090788                62189            1
# 1924406                62189            2
# 2459734                62189            1
# 3103159                62189            2
# 3103161                62189            1
# 3568708                62189            1
# 3700910                62189            1
# 4459307                62189            2
# 4797179                62189            1

# %%
# Bus 100
# No origin-destination total_trips data for this route?

origin = 11009
destination = 66009
df[(df['ORIGIN_PT_CODE'] == origin) & (df['DESTINATION_PT_CODE'] == destination)]
# df[(df['ORIGIN_PT_CODE'] == origin)]
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 295840     2024-02           WEEKDAY             12     BUS           11009
# 401694     2024-02           WEEKDAY             19     BUS           11009
# 401695     2024-02  WEEKENDS/HOLIDAY             19     BUS           11009
# 907393     2024-02  WEEKENDS/HOLIDAY             21     BUS           11009
# 907394     2024-02           WEEKDAY             21     BUS           11009
# 1198918    2024-02  WEEKENDS/HOLIDAY              9     BUS           11009
# 1318349    2024-02  WEEKENDS/HOLIDAY             16     BUS           11009
# 1318350    2024-02           WEEKDAY             16     BUS           11009
# 1724755    2024-02           WEEKDAY             14     BUS           11009
# 1724756    2024-02  WEEKENDS/HOLIDAY             14     BUS           11009
# 2637636    2024-02           WEEKDAY             18     BUS           11009
# 2637637    2024-02  WEEKENDS/HOLIDAY             18     BUS           11009
# 3324684    2024-02           WEEKDAY             20     BUS           11009
# 3324685    2024-02  WEEKENDS/HOLIDAY             20     BUS           11009
# 3476667    2024-02  WEEKENDS/HOLIDAY             11     BUS           11009
# 3476668    2024-02           WEEKDAY             11     BUS           11009
# 3921835    2024-02           WEEKDAY             22     BUS           11009
# 3984632    2024-02  WEEKENDS/HOLIDAY             13     BUS           11009
# 3984633    2024-02           WEEKDAY             13     BUS           11009
# 3997830    2024-02  WEEKENDS/HOLIDAY              6     BUS           11009
# 3997831    2024-02           WEEKDAY              6     BUS           11009
# 4335107    2024-02  WEEKENDS/HOLIDAY             15     BUS           11009
# 4335108    2024-02           WEEKDAY             15     BUS           11009
# 4962329    2024-02           WEEKDAY             10     BUS           11009
# 5210993    2024-02           WEEKDAY             17     BUS           11009
# 5210994    2024-02  WEEKENDS/HOLIDAY             17     BUS           11009
# 5347611    2024-02           WEEKDAY              8     BUS           11009
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 295840                 66009            3
# 401694                 66009            5
# 401695                 66009            1
# 907393                 66009            6
# 907394                 66009            1
# 1198918                66009            1
# 1318349                66009            1
# 1318350                66009            6
# 1724755                66009           10
# 1724756                66009            3
# 2637636                66009            2
# 2637637                66009            1
# 3324684                66009            1
# 3324685                66009            1
# 3476667                66009            2
# 3476668                66009            1
# 3921835                66009            8
# 3984632                66009            4
# 3984633                66009            7
# 3997830                66009            1
# 3997831                66009            1
# 4335107                66009            3
# 4335108                66009            6
# 4962329                66009            3
# 5210993                66009            4
# 5210994                66009            2
# 5347611                66009            2

# %%
# Bus 100
# Direction 1 has same total trips as Direction 2?
    # Findings: seems not

origin = 66009
destination = 11009
df[(df['ORIGIN_PT_CODE'] == origin) & (df['DESTINATION_PT_CODE'] == destination)]
# df[(df['ORIGIN_PT_CODE'] == origin)]
# Out:
#         YEAR_MONTH DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 1318351    2024-02  WEEKDAY             16     BUS           66009
# 1724757    2024-02  WEEKDAY             14     BUS           66009
# 3997829    2024-02  WEEKDAY              6     BUS           66009
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 1318351                11009            1
# 1724757                11009            1
# 3997829                11009           13

# %%
# Bus 10

origin = 75009
destination = 16009
df[(df['ORIGIN_PT_CODE'] == origin) & (df['DESTINATION_PT_CODE'] == destination)]
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 13929      2024-02           WEEKDAY              9     BUS           75009
# 795985     2024-02           WEEKDAY             11     BUS           75009
# 795987     2024-02  WEEKENDS/HOLIDAY             11     BUS           75009
# 1111922    2024-02           WEEKDAY             22     BUS           75009
# 1111924    2024-02  WEEKENDS/HOLIDAY             22     BUS           75009
# 1187255    2024-02  WEEKENDS/HOLIDAY              7     BUS           75009
# 1187256    2024-02           WEEKDAY              7     BUS           75009
# 1625229    2024-02           WEEKDAY             13     BUS           75009
# 1625230    2024-02  WEEKENDS/HOLIDAY             13     BUS           75009
# 1805412    2024-02           WEEKDAY              6     BUS           75009
# 2701475    2024-02  WEEKENDS/HOLIDAY             21     BUS           75009
# 2963833    2024-02           WEEKDAY             15     BUS           75009
# 2963834    2024-02  WEEKENDS/HOLIDAY             15     BUS           75009
# 3722907    2024-02  WEEKENDS/HOLIDAY             14     BUS           75009
# 3722909    2024-02           WEEKDAY             14     BUS           75009
# 4409518    2024-02           WEEKDAY             16     BUS           75009
# 4704847    2024-02  WEEKENDS/HOLIDAY             12     BUS           75009
# 4704848    2024-02           WEEKDAY             12     BUS           75009
# 4796389    2024-02  WEEKENDS/HOLIDAY              5     BUS           75009
# 4796390    2024-02           WEEKDAY              5     BUS           75009
# 5059756    2024-02  WEEKENDS/HOLIDAY             18     BUS           75009
# 5059758    2024-02           WEEKDAY             18     BUS           75009
# 5430267    2024-02           WEEKDAY             20     BUS           75009
# 5430268    2024-02  WEEKENDS/HOLIDAY             20     BUS           75009
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 13929                  16009            1
# 795985                 16009            3
# 795987                 16009            2
# 1111922                16009            1
# 1111924                16009            1
# 1187255                16009            1
# 1187256                16009            1
# 1625229                16009            8
# 1625230                16009            4
# 1805412                16009            1
# 2701475                16009            2
# 2963833                16009            2
# 2963834                16009            3
# 3722907                16009            4
# 3722909                16009            4
# 4409518                16009            3
# 4704847                16009            9
# 4704848                16009            6
# 4796389                16009            4
# 4796390                16009            8
# 5059756                16009            1
# 5059758                16009            1
# 5430267                16009            2
# 5430268                16009            3

# %%
origin = 16009
destination = 75009
df[(df['ORIGIN_PT_CODE'] == origin) & (df['DESTINATION_PT_CODE'] == destination)]
# Out:
#         YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE  ORIGIN_PT_CODE  \
# 13928      2024-02           WEEKDAY              9     BUS           16009
# 795986     2024-02           WEEKDAY             11     BUS           16009
# 1111923    2024-02  WEEKENDS/HOLIDAY             22     BUS           16009
# 1625228    2024-02           WEEKDAY             13     BUS           16009
# 1859554    2024-02           WEEKDAY             19     BUS           16009
# 2161372    2024-02           WEEKDAY             17     BUS           16009
# 2161373    2024-02  WEEKENDS/HOLIDAY             17     BUS           16009
# 2701474    2024-02           WEEKDAY             21     BUS           16009
# 2963835    2024-02  WEEKENDS/HOLIDAY             15     BUS           16009
# 2963836    2024-02           WEEKDAY             15     BUS           16009
# 3183622    2024-02           WEEKDAY             10     BUS           16009
# 3183623    2024-02  WEEKENDS/HOLIDAY             10     BUS           16009
# 3722908    2024-02           WEEKDAY             14     BUS           16009
# 3722910    2024-02  WEEKENDS/HOLIDAY             14     BUS           16009
# 4164878    2024-02           WEEKDAY             23     BUS           16009
# 4164879    2024-02  WEEKENDS/HOLIDAY             23     BUS           16009
# 4409517    2024-02  WEEKENDS/HOLIDAY             16     BUS           16009
# 4409519    2024-02           WEEKDAY             16     BUS           16009
# 4704846    2024-02           WEEKDAY             12     BUS           16009
# 5059755    2024-02           WEEKDAY             18     BUS           16009
# 5059757    2024-02  WEEKENDS/HOLIDAY             18     BUS           16009
# 5430269    2024-02           WEEKDAY             20     BUS           16009
#
#          DESTINATION_PT_CODE  TOTAL_TRIPS
# 13928                  75009            2
# 795986                 75009            3
# 1111923                75009            1
# 1625228                75009            3
# 1859554                75009            1
# 2161372                75009            2
# 2161373                75009            1
# 2701474                75009            3
# 2963835                75009            1
# 2963836                75009            3
# 3183622                75009            2
# 3183623                75009            2
# 3722908                75009           10
# 3722910                75009            7
# 4164878                75009            1
# 4164879                75009            1
# 4409517                75009            4
# 4409519                75009            2
# 4704846                75009            3
# 5059755                75009            4
# 5059757                75009            1
# 5430269                75009            3
